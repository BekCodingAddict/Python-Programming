# %%
import array

my_arr=array.array('i',[1,2,3,4,5])
print(my_arr)
print(type(my_arr))
# Out:
# array('i', [1, 2, 3, 4, 5])
# <class 'array.array'>

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import random 

print(random.randint(1,100))
fruit=random.choice(["apple","banana","cherry"])
print(fruit)
# Out:
# 64
# cherry

# %%
import os 
print(os.getcwd())
# Out:
# d:\Python\Python-Programming\Complete_Agentic_AI_Bootcamp_with_LangGraph_and_LangChain\Section_3_Python_Prerequisites\5-Modules_and_Packages

# %%
os.makedirs("my_directory") ## creates a new directory

# %%
## High level operations
import shutil
shutil.copy("source.txt","destination.txt")
# Out:
# 'destination.txt'

# %%
## Data Serialization
import json

data={"name":"John","age":30,"city":"New York"}
json_data=json.dumps(data)
print(json_data)
print(type(json_data))
json_data=json.loads(json_data)
print(json_data)
print(type(json_data))
# Out:
# {"name": "John", "age": 30, "city": "New York"}
# <class 'str'>
# {'name': 'John', 'age': 30, 'city': 'New York'}
# <class 'dict'>

# %%
import csv

with open("data.csv","w") as file:
    writer=csv.writer(file)
    writer.writerow(["Name","Age","City"])
    writer.writerow(["John",30,"New York"])
    writer.writerow(["Jane",25,"Los Angeles"])

# %%
with open("data.csv","r") as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['John', '30', 'New York']
# ['Jane', '25', 'Los Angeles']

# %%
from datetime import datetime,timedelta

today=datetime.now()
print(today)

yesterday=today-timedelta(days=1)
print(yesterday)
# Out:
# 2025-11-10 00:58:45.894256
# 2025-11-09 00:58:45.894256

# %%
import time
print(time.time())
time.sleep(2)
print("2 seconds later")
print(time.time())
# Out:
# 1762703998.0689137
# 2 seconds later
# 1762704000.0702732

# %%
import re
pattern=r"\d+"
text="Hello 123 and 456"
matches=re.findall(pattern,text)
print(matches)
# Out:
# ['123', '456']
