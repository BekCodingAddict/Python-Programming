# %%
## Importing packages
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi

print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
# !pip install numpy
# Out:
# ...
#   Using cached numpy-2.3.4-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.8 MB 9.4 MB/s eta 0:00:02
#    --------- ------------------------------ 2.9/12.8 MB 10.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.8 MB 11.1 MB/s eta 0:00:01
#    ------------------------ --------------- 7.9/12.8 MB 11.4 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.8 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 11.1 MB/s  0:00:01
# ...

# %%
import numpy as np

np.array([1,2,3,4,5])

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from package.maths import add,subtract,multiply,divide
print(add(10,20))
print(subtract(10,20))
print(multiply(10,20))
print(divide(10,20))
# Out:
# 30
# -10
# 200
# 0.5

# %%
# Importing all functions from a module
from package.maths import *
print(add(10,20))
print(subtract(10,20))
print(multiply(10,20))
print(divide(10,20))

# Importing all functions from a subpackage
from package.subpackages.sub_math import *
print(square(10))
print(cube(10))
# Out:
# 30
# -10
# 200
# 0.5
# 100
# 1000
