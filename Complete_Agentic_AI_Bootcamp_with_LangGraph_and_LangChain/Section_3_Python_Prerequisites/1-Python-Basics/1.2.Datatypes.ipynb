# %%
## Integer Examples
age=32
print(type(age))
# Out:
# <class 'int'>

# %%
## float Examples
height=5.9
print(type(height))
# Out:
# <class 'float'>

# %%
## String Examples
name="John"
print(name)
print(type(name))
# Out:
# John
# <class 'str'>

# %%
## Boolean Examples
is_student=True
print(is_student)
print(type(is_student))
# Out:
# True
# <class 'bool'>

# %%
is_bool=bool()
print(is_bool)
print(type(is_bool))
# Out:
# False
# <class 'bool'>

# %%
a=10
b=10
print(type(a==b))
# Out:
# <class 'bool'>

# %%
## common errors
#result="Hello" + 10 ## TypeError: can only concatenate str (not "int") to str
result="Hello" + str(10)
print(result)
# Out:
# Hello10

# %%
str1="Hello"
