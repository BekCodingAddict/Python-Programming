# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
# ...

# %%
import pandas as pd

## Series is a one-dimensional array-like object that can hold any data type.
series=pd.Series([1,2,3,4,5])
print(series)
print(type(series))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
#Create a series from a dictionary
data={'a':10,'b':20,'c':30}
series=pd.Series(data)
print(series)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
data=[10,20,30,40,50]
index=['a','b','c','d','e']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
import string
s = pd.Series(range(26), index=list(string.ascii_lowercase))
print(s)
# Out:
# a     0
# b     1
# c     2
# d     3
# e     4
# f     5
# g     6
# h     7
# i     8
# j     9
# k    10
# l    11
# m    12
# n    13
# o    14
# p    15
# q    16
# r    17
# s    18
# t    19
# u    20
# v    21
# w    22
# x    23
# y    24
# z    25
# dtype: int64

# %%
# DataFrames
# create a dataframe from a dictionary
data={
    "Name":["Alice","Bob","Charlie"],
    "Age":[25,30,35],
    "City":["New York","Los Angeles","Chicago"]
}
df=pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
import numpy as np
np.array(df)
# Out:
# array([['Alice', 25, 'New York'],
#        ['Bob', 30, 'Los Angeles'],
#        ['Charlie', 35, 'Chicago']], dtype=object)

# %%
## Create a dataframe from a list of dictionaries
data=[
    {"Name":"Alice","Age":25,"City":"New York"},
    {"Name":"Bob","Age":30,"City":"Los Angeles"},
    {"Name":"Charlie","Age":35,"City":"Chicago"}
]
df=pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df=pd.read_csv("muck_data.csv")
df.head()
# Out:
#    id     name  age         city  purchase_amount
# 0   1    Alice   25     New York           120.50
# 1   2      Bob   30  Los Angeles           340.00
# 2   3  Charlie   22      Chicago            89.99
# 3   4    Diana   28      Houston           150.00
# 4   5    Ethan   35      Phoenix           220.75

# %%
df.tail()
# Out:
#    id    name  age          city  purchase_amount
# 5   6   Fiona   29  Philadelphia           410.00
# 6   7  George   40   San Antonio           310.25
# 7   8  Hannah   27     San Diego           270.10
# 8   9     Ian   32        Dallas           190.00
# 9  10   Julia   24      San Jose           130.60

# %%
df["purchase_amount"]
# Out:
# 0    120.50
# 1    340.00
# 2     89.99
# 3    150.00
# 4    220.75
# 5    410.00
# 6    310.25
# 7    270.10
# 8    190.00
# 9    130.60
# Name: purchase_amount, dtype: float64

# %%
df.loc[0]
# Out:
# id                        1
# name                  Alice
# age                      25
# city               New York
# purchase_amount       120.5
# Name: 0, dtype: object

# %%
## Accessing specific rows and columns
df.iloc[0]
# Out:
# id                        1
# name                  Alice
# age                      25
# city               New York
# purchase_amount       120.5
# Name: 0, dtype: object

# %%
df.at[0,"purchase_amount"]
# Out:
# np.float64(120.5)

# %%
## Data Manipulation with DataFrames
df['Salary']=df['purchase_amount']*1.1

# %%
df.head()
df.drop(columns=["Salary"],inplace=True)
df.head()
# Out:
#    id     name  age         city  purchase_amount
# 0   1    Alice   25     New York           120.50
# 1   2      Bob   30  Los Angeles           340.00
# 2   3  Charlie   22      Chicago            89.99
# 3   4    Diana   28      Houston           150.00
# 4   5    Ethan   35      Phoenix           220.75

# %%
## Add a new column to the dataframe
df['Salary']=df['purchase_amount']*1.1
df.head()
# Out:
#    id     name  age         city  purchase_amount   Salary
# 0   1    Alice   25     New York           120.50  132.550
# 1   2      Bob   30  Los Angeles           340.00  374.000
# 2   3  Charlie   22      Chicago            89.99   98.989
# 3   4    Diana   28      Houston           150.00  165.000
# 4   5    Ethan   35      Phoenix           220.75  242.825
