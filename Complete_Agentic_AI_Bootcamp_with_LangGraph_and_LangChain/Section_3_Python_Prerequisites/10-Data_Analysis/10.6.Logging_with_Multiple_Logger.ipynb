# %%
import logging

logger1=logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

logger2=logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
    )

logger1.addHandler(logging.StreamHandler())
logger2.addHandler(logging.StreamHandler())

logger1.debug("This is a debug message from module1")
logger2.debug("This is a debug message from module2")
# Out:
# This is a debug message from module1
# 2025-11-13 03:26:17 - module1 - DEBUG - This is a debug message from module1
