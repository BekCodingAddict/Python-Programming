# %%
## function copy
def my_function():
    print("Hello, World!")

my_function()
# Out:
# Hello, World!

# %%
func=my_function
func()
del my_function
func()
# Out:
# Hello, World!
# Hello, World!

# %%
## Closure
def outer_function(msg):
    message = msg
    def inner_function():
        print("Inner function: " + message)
    return inner_function

hi_func = outer_function("Hi")
hi_func()
# Out:
# Inner function: Hi

# %%
def increase(x):
    sum=x
    def increase_by_two(y):
        nonlocal sum
        sum=sum+y
        return sum
    return increase_by_two

increase_by_two = increase(2)
print(increase_by_two(10))  
print(increase_by_two(10))  
print(increase_by_two(10))  

def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper

def hello_world():
    print("Hello, World!")

hello_world = my_decorator(hello_world)
hello_world()

def hello_world():
    print("Hello, World!")
# Out:
# 12
# 22
# 32
# Something is happening before the function is called.
# Hello, World!
# Something is happening after the function is called.

# %%
## Decorator
def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper


def hello_world():
    print("Hello, World!")

@my_decorator
def hello_world():
    print("Hello, World!")

hello_world()
# Out:
# Something is happening before the function is called.
# Hello, World!
# Something is happening after the function is called.

# %%
def debug(func):
    def wrapper(*args, **kwargs):
        print(f"Calling {func.__name__} with {args=} and {kwargs=}")
        result = func(*args, **kwargs)
        print(f"{func.__name__} returned {result}")
        return result
    return wrapper

@debug
def add(a, b):
    return a + b

add(5, 3)
# Out:
# Calling add with args=(5, 3) and kwargs={}
# add returned 8
# 8

# %%
import time

def timer(func):
    def wrapper(*args, **kwargs):
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()
        print(f"{func.__name__} ran in {end - start:.4f} seconds")
        return result
    return wrapper

@timer
def slow_function():
    time.sleep(2)
    return "Done!"

slow_function()
# Out:
# slow_function ran in 2.0008 seconds
# 'Done!'

# %%
def require_login(func):
    def wrapper(user):
        if not user.get("logged_in"):
            print("Access denied. Please log in.")
            return
        return func(user)
    return wrapper

@require_login
def view_dashboard(user):
    print(f"Welcome {user['name']} to your dashboard!")

user1 = {"name": "Alice", "logged_in": True}
user2 = {"name": "Bob", "logged_in": False}

view_dashboard(user1)
view_dashboard(user2)
# Out:
# Welcome Alice to your dashboard!
# Access denied. Please log in.
