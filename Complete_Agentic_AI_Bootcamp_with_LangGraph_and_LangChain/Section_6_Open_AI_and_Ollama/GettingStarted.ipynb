# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
## Langchain Tracking
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "True"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x0000026EA3DEFD60> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000026EA3DEEA10> root_client=<openai.OpenAI object at 0x0000026EA3DEFC40> root_async_client=<openai.AsyncOpenAI object at 0x0000026EA3DEEC50> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
### Imput Prompt and get response
prompt="What is General AI? "
response=llm.invoke(prompt)
print(response)
# Out:
# content='General AI, also known as Artificial General Intelligence (AGI), refers to a type of artificial intelligence that possesses the ability to understand, learn, and apply knowledge across a wide range of tasks at a level comparable to human intelligence. Unlike narrow AI, which is designed to perform specific tasks like language translation, facial recognition, or playing chess, General AI would be capable of performing any intellectual task that a human can do.\n\nKey characteristics of General AI include:\n\n1. **Versatility:** The ability to perform a wide variety of tasks rather than being limited to a specific function.\n2. **Learning and Adaptation:** The capacity to learn from experience and adapt to new situations without needing to be specifically programmed for each task.\n3. **Reasoning and Problem Solving:** The ability to reason, plan, and solve problems in situations not encountered before.\n4. **Understanding Context and Emotions:** The ability to comprehend and 
# ...

# %%
### Chatprompt template
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages([
    ("system","You are an Expert AI Engineer. Provide a detailed answer to the question."),
    ("user",f"{input}")
])

chain=prompt|llm
response=chain.invoke({"input":"What is General AI?"})
print(response)
# Out:
# content='It seems there might be some misunderstanding in the inquiry. The snippet `"<bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x0000026E8BCE5570>>"` is an object representation in Python related to an IPython or Jupyter Notebook environment. Here\'s what this means:\n\n1. **IPython/Jupyter Kernel**: IPython provides a powerful interactive shell and Jupyter Notebooks use this, or a similar kernel system, to execute code in various languages. In your environment, the `IPythonKernel` object is running, managing the code execution.\n\n2. **`raw_input` Method**: The `raw_input` (now simply `input` in Python 3) function is a method to read a line from input, which is typically the console. However, in this context, it is bound within the kernel object, which possibly attempts to handle or manage input within this interactive session.\n\n3. **Callback/Lambda Function**: The `bound method` implies that this is a method ready to be invoked on the kernel ob
# ...

# %%
chain = prompt | llm

response=chain.invoke({"input":"Can you tell me about LangGraph?"})
print(response)
# Out:
# content="It seems you've posted a command that is part of the IPython or Jupyter Notebook interface, rather than a direct question. The command `Kernel.raw_input` is a method related to capturing input within the kernel process of an IPython session. Specifically, it's used internally for reading input, which is generally triggered by the `input()` function when running scripts interactively.\n\nIn an interactive Python session like Jupyter or IPython, the kernel facilitates communication between the code execution environment and the user interface. The `raw_input` method is part of the underlying mechanisms that handle user input requests, though in modern Python (3.x and later), the `raw_input()` function has been replaced by `input()` for similar functionality—it's used to take input from the user as a string.\n\nIf you have a specific question or need assistance with any aspect of using IPython, Jupyter Notebooks, or coding in Python, feel free to ask with more context or detail
# ...

# %%
### String output parser
from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()

chain = prompt | llm | output_parser

response=chain.invoke({"input":"Can you tell me about LangGraph?"})
print(response)
# Out:
# It appears that you've pasted an internal method reference from the IPython kernel, likely by accident. This `<bound method Kernel.raw_input>` is an internal Python object representation showing a method bound to an instance of the `IPythonKernel` object.
#
# In Python, and particularly within environments like Jupyter notebooks, when methods like `raw_input` are mentioned, they usually involve capturing input from a user. Specifically, `raw_input` is a Python 2 function (replaced by `input` in Python 3) used to read a line from input, usually from the user. However, the code snippet you've posted doesn't represent any executable or interpretable code. Instead, it's merely a textual representation of a method that is part of the kernel’s code execution machinery in a Jupyter environment.
#
# If you are encountering this in error or unexpectedly within a Jupyter notebook or another interactive Python environment, here are a few suggestions:
#
# ...
